# %% [markdown]
# # Extract data summary
#
# This notebook uses the `TrialProcessor` class to extract various metrics for all trials.
#
# This came from `fig_extract_data_summary_20230417.ipynb` in the original repo.

# %%
from pathlib import Path

import numpy as np
import pandas as pd

from pp_utils.core import generate_data_path_dict
from pp_utils.file_handling import df_main_loader
from pp_utils.trial_processor import TrialProcessor
from pp_utils.misc import interp_xy

import pickle

# %% [markdown]
# ## Set paths and load main info df

# %%
data_path = generate_data_path_dict(Path("../data_processed/"))
raw_path = Path("../data_raw/")

# %% [markdown]
# ### Output path

# %%
output_path = data_path["main"] / "data_summary"
if not output_path.exists():
    output_path.mkdir()

# %%
tp_output_path = output_path / "trial_processor_object"
if not tp_output_path.exists():
    tp_output_path.mkdir()

# %% [markdown]
# ### Load main dataframe

# %%
df_main = df_main_loader(
    folder=data_path["info_csv"], filename="main_info_append_09.csv",
)

# %% [markdown]
# ## Processing params

# %%
from pp_utils.core import MISC_PARAMS, HYDRO_PARAMS, ENV_PARAMS, SCAN_PARAMS

# %%
MISC_PARAMS
# Out:
# {'th_RL': 140,
#  'time_binning_delta': 0.05,
#  'buzz_reg_switch': 0.013,
#  'num_buzz_for_onset': 30,
#  'dist_max': ('DTAG_dist_elliptical', 12),
#  'dist_min': ('ROSTRUM_dist_to_target', 0.1)}

# %%
HYDRO_PARAMS
# Out:
# {'bkg_len_sec': 3.2e-05,
#  'clk_sel_len_sec': 0.000128,
#  'perc_before_pk': 30,
#  'hydro_sens': -211,
#  'recording_gain': 40}

# %%
ENV_PARAMS
# Out:
# {'frequency': 130000.0,
#  'temperature': 16,
#  'salinity': 28,
#  'pressure': 1,
#  'pH': 8,
#  'absorption_formula_source': 'FG'}

# %%
SCAN_PARAMS
# Out:
# {'RL_tolerance': 5,
#  'th_num_clk': 5,
#  'true_scan_th_RL_diff': 5,
#  'true_scan_max_num_click_has_RL_diff': 3}

# %% [markdown]
# ## Extract data summary

# %%
SCAN_FIELDS = ("scan_ch0", "scan_ch1", "scan_combined")
TIME_FIELDS = (
    "time_decision", "time_buzz_onset_dtag", "time_buzz_onset_hydro",
    "time_touch", "time_last_nonchosen",
)
RANGE_FIELDS = (
    "range_decision_tar", "range_buzz_onset_dtag_tar", "range_buzz_onset_hydro_tar",
    "range_decision_clu", "range_buzz_onset_dtag_clu", "range_buzz_onset_hydro_clu",
)
ANGLE_FIELDS = (
    "angle_range_target", "angle_range_clutter", "angle_last_scan",
)

# %%
df_track_all = []
df_track_portion_all = []
time_all = []
range_all = []
scan_num_all = []
angle_all = []

# %%
# Loop through all trials
for trial_idx in df_main.index:

    # Init entry
    time_dict = dict.fromkeys(TIME_FIELDS)
    range_dict = dict.fromkeys(RANGE_FIELDS)
    angle_dict = dict.fromkeys(ANGLE_FIELDS)
    scan_dict = dict.fromkeys(SCAN_FIELDS)
    track_all_entry = None
    track_portion_entry = None
    
    # Process trial
    tp = TrialProcessor(df_main, trial_idx, data_path, raw_path)
    
    if tp.trial_usable is True:
        
        # Add track and hydrophone features
        tp.add_track_features()
        tp.add_hydro_features()
        tp.add_SNR_p2p(hydro_params=HYDRO_PARAMS)
        tp.add_RL_ASL_pointEL(hydro_params=HYDRO_PARAMS, env_params=ENV_PARAMS)
        tp.add_before_touch_to_all_dfs()

        # Scan
        tp.get_hydro_scan_num(th_RL=MISC_PARAMS["th_RL"], scan_params=SCAN_PARAMS)
        df_scan_ch0 = tp.sort_df_scan_to_channel(ch=0)
        df_scan_ch1 = tp.sort_df_scan_to_channel(ch=1)

        # Decision
        decision_click = tp.decision_hydro_click_from_scan()

        # Buzz onset
        buzz_onset_dtag = tp.get_dtag_buzz_onset(
            buzz_reg_switch=MISC_PARAMS["buzz_reg_switch"],
            num_buzz_for_onset=MISC_PARAMS["num_buzz_for_onset"]
        )
        buzz_onset_hydro = tp.get_hydro_buzz_onset(
            buzz_reg_switch=MISC_PARAMS["buzz_reg_switch"],
            num_buzz_for_onset=MISC_PARAMS["num_buzz_for_onset"]
        )

        # Positions
        decision_pos = interp_xy(decision_click["time_corrected"], tp.df_track)
        buzz_onset_dtag_pos = interp_xy(buzz_onset_dtag["time_corrected"], tp.df_track)
        buzz_onset_hydro_pos = interp_xy(buzz_onset_hydro["time_corrected"], tp.df_track)
        
        # Inspection angle
        angle_ch0_in_cam, angle_ch1_in_cam = tp.get_inspection_angle_in_view(
            time_stop=decision_click["time_corrected"],
            th_RL=MISC_PARAMS["th_RL"],
            time_binning_delta=MISC_PARAMS["time_binning_delta"]
        )
        
        # Last scan start/end time
        tp.get_timing_last_scan_of_nonselect()

    
        # Collect info for each trial -------------------------------

        track_all_entry = tp.df_track
        track_portion_entry = tp.get_desired_track_portion(
            dist_max=MISC_PARAMS["dist_max"], dist_min=MISC_PARAMS["dist_min"]
        )
        
        scan_dict.update({
            "scan_ch0": len(df_scan_ch0),      # scan toward ch0
            "scan_ch1": len(df_scan_ch1),      # scan toward ch1
            "scan_combined": len(tp.df_scan),  # all scans across 2 ch
        })

        time_dict.update({
            "time_decision": decision_click["time_corrected"],  # decision time
            "time_buzz_onset_dtag": buzz_onset_dtag["time_corrected"],  # buzz onset identified in dtag
            "time_buzz_onset_hydro": buzz_onset_hydro["time_corrected"],  # buzz onset identified in hydro
            "time_touch": tp.df_dtag[tp.df_dtag["before_touch"]].iloc[-1]["time_corrected"],  # touch time
            "time_last_nonchosen": tp.duration_last_scan_of_nonselect(),  # last scan duration
        })

        if tp.trial_series["TARGET_ANGLE"][:2] == "TC":
            pos_tar, pos_clu = [0, -1], [0, 0]
        else:
            pos_tar, pos_clu = [0, 0], [0, -1]
        range_dict.update({
            "range_decision_tar": np.linalg.norm(decision_pos - pos_tar),
            "range_buzz_onset_dtag_tar": np.linalg.norm(buzz_onset_dtag_pos - pos_tar),
            "range_buzz_onset_hydro_tar": np.linalg.norm(buzz_onset_hydro_pos - pos_tar),
            "range_decision_clu": np.linalg.norm(decision_pos - pos_clu),
            "range_buzz_onset_dtag_clu": np.linalg.norm(buzz_onset_dtag_pos - pos_clu),
            "range_buzz_onset_hydro_clu": np.linalg.norm(buzz_onset_hydro_pos - pos_clu),
        })
        
        angle_dict.update({
            "angle_range_target": (
                None if angle_ch0_in_cam.size == 0 else angle_ch0_in_cam.max() - angle_ch0_in_cam.min() 
            ),
            "angle_range_clutter": (
                None if angle_ch1_in_cam.size == 0 else angle_ch1_in_cam.max() - angle_ch1_in_cam.min() 
            ),
            "angle_last_scan": tp.angle_span_last_scan_of_nonselect(),
        })
        
    # Append to list
    df_track_all.append(track_all_entry)
    df_track_portion_all.append(track_portion_entry)
    scan_num_all.append(list(scan_dict.values()))
    time_all.append(list(time_dict.values()))
    range_all.append(list(range_dict.values()))
    angle_all.append(list(angle_dict.values()))
    
    # Save the TrialProcessor object
    with open(tp_output_path / f"trial_{trial_idx:03d}.pickle", "wb") as fileout:
        pickle.dump(tp, fileout)
# Out:
# ------ trial 0 ------------
# 20190625_s1_t0
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 1 ------------
# 20190625_s1_t0
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 2 ------------
# 20190625_s1_t1
# * cal object selected: hula_flip
# * track file:     20190625_s1_t1_GOPR1466_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s1_t1_dtag.csv
# * hydro ch0 file: 20190625_s1_t1_hydro_ch0.csv
# * hydro ch1 file: 20190625_s1_t1_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 3 ------------
# 20190625_s1_t2
# * cal object selected: hula_flip
# * track file:     20190625_s1_t2_GOPR1466_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s1_t2_dtag.csv
# * hydro ch0 file: 20190625_s1_t2_hydro_ch0.csv
# * hydro ch1 file: 20190625_s1_t2_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 4 ------------
# 20190625_s1_t3
# * cal object selected: hula_flip
# * track file:     20190625_s1_t3_GOPR1466_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s1_t3_dtag.csv
# * hydro ch0 file: 20190625_s1_t3_hydro_ch0.csv
# * hydro ch1 file: 20190625_s1_t3_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 5 ------------
# 20190625_s1_t4
# * cal object selected: hula_flip
# * track file:     20190625_s1_t4_GOPR1466_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s1_t4_dtag.csv
# * hydro ch0 file: 20190625_s1_t4_hydro_ch0.csv
# * hydro ch1 file: 20190625_s1_t4_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 6 ------------
# 20190625_s1_t5
# * cal object selected: hula_flip
# * track file:     20190625_s1_t5_GOPR1466_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s1_t5_dtag.csv
# * hydro ch0 file: 20190625_s1_t5_hydro_ch0.csv
# * hydro ch1 file: 20190625_s1_t5_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 7 ------------
# 20190625_s1_t6
# * cal object selected: hula_flip
# * track file:     20190625_s1_t6_GP011466_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s1_t6_dtag.csv
# * hydro ch0 file: 20190625_s1_t6_hydro_ch0.csv
# * hydro ch1 file: 20190625_s1_t6_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 8 ------------
# 20190625_s2_t1
# * cal object selected: hula_flip
# * track file:     20190625_s2_t1_GOPR1467_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s2_t1_dtag.csv
# * hydro ch0 file: 20190625_s2_t1_hydro_ch0.csv
# * hydro ch1 file: 20190625_s2_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 9 ------------
# 20190625_s2_t2
# * cal object selected: hula_flip
# * track file:     20190625_s2_t2_GOPR1467_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s2_t2_dtag.csv
# * hydro ch0 file: 20190625_s2_t2_hydro_ch0.csv
# * hydro ch1 file: 20190625_s2_t2_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 10 ------------
# 20190625_s2_t3
# * cal object selected: hula_flip
# * track file:     20190625_s2_t3_GOPR1467_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s2_t3_dtag.csv
# * hydro ch0 file: 20190625_s2_t3_hydro_ch0.csv
# * hydro ch1 file: 20190625_s2_t3_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 11 ------------
# 20190625_s2_t4
# * cal object selected: hula_flip
# * track file:     20190625_s2_t4_GOPR1467_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s2_t4_dtag.csv
# * hydro ch0 file: 20190625_s2_t4_hydro_ch0.csv
# * hydro ch1 file: 20190625_s2_t4_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 12 ------------
# 20190625_s2_t5
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 13 ------------
# 20190625_s2_t6
# * cal object selected: hula_flip
# * track file:     20190625_s2_t6_GOPR1467_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s2_t6_dtag.csv
# * hydro ch0 file: 20190625_s2_t6_hydro_ch0.csv
# * hydro ch1 file: 20190625_s2_t6_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 14 ------------
# 20190625_s2_t7
# * cal object selected: hula_flip
# * track file:     20190625_s2_t7_GOPR1467_xypressure_hula_flip_transformed.csv
# * dtag file:      20190625_s2_t7_dtag.csv
# * hydro ch0 file: 20190625_s2_t7_hydro_ch0.csv
# * hydro ch1 file: 20190625_s2_t7_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 15 ------------
# 20190625_s2_t8
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 16 ------------
# 20190625_s3_t1
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 17 ------------
# 20190625_s3_t2
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 18 ------------
# 20190625_s3_t3
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 19 ------------
# 20190625_s3_t4
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 20 ------------
# 20190625_s3_t5
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 21 ------------
# 20190625_s3_t6
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 22 ------------
# 20190625_s3_t7
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 23 ------------
# 20190625_s3_t8
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 24 ------------
# 20190625_s3_t9
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 25 ------------
# 20190625_s3_t10
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 26 ------------
# 20190626_s1_t1
# * cal object selected: hula_flip
# * track file:     20190626_s1_t1_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t1_dtag.csv
# * hydro ch0 file: 20190626_s1_t1_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t1_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 27 ------------
# 20190626_s1_t2
# * cal object selected: hula_flip
# * track file:     20190626_s1_t2_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t2_dtag.csv
# * hydro ch0 file: 20190626_s1_t2_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t2_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 28 ------------
# 20190626_s1_t3
# * cal object selected: hula_flip
# * track file:     20190626_s1_t3_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t3_dtag.csv
# * hydro ch0 file: 20190626_s1_t3_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t3_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 29 ------------
# 20190626_s1_t4
# * cal object selected: hula_flip
# * track file:     20190626_s1_t4_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t4_dtag.csv
# * hydro ch0 file: 20190626_s1_t4_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t4_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 30 ------------
# 20190626_s1_t5
# * cal object selected: hula_flip
# * track file:     20190626_s1_t5_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t5_dtag.csv
# * hydro ch0 file: 20190626_s1_t5_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t5_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 31 ------------
# 20190626_s1_t6
# * cal object selected: hula_flip
# * track file:     20190626_s1_t6_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t6_dtag.csv
# * hydro ch0 file: 20190626_s1_t6_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t6_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 32 ------------
# 20190626_s1_t7
# * cal object selected: hula_flip
# * track file:     20190626_s1_t7_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t7_dtag.csv
# * hydro ch0 file: 20190626_s1_t7_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t7_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 33 ------------
# 20190626_s1_t8
# * cal object selected: hula_flip
# * track file:     20190626_s1_t8_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t8_dtag.csv
# * hydro ch0 file: 20190626_s1_t8_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t8_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
# ------ trial 34 ------------
# 20190626_s1_t9
# * cal object selected: hula_flip
# * track file:     20190626_s1_t9_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t9_dtag.csv
# * hydro ch0 file: 20190626_s1_t9_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t9_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 35 ------------
# 20190626_s1_t10
# * cal object selected: hula_flip
# * track file:     20190626_s1_t10_GOPR1469_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s1_t10_dtag.csv
# * hydro ch0 file: 20190626_s1_t10_hydro_ch0.csv
# * hydro ch1 file: 20190626_s1_t10_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 36 ------------
# 20190626_s2_t1
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t1_GOPR1470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t1_dtag.csv
# * hydro ch0 file: 20190626_s2_t1_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 37 ------------
# 20190626_s2_t2
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t2_GOPR1470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t2_dtag.csv
# * hydro ch0 file: 20190626_s2_t2_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t2_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 38 ------------
# 20190626_s2_t3
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t3_GOPR1470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t3_dtag.csv
# * hydro ch0 file: 20190626_s2_t3_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t3_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 39 ------------
# 20190626_s2_t4
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t4_GOPR1470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t4_dtag.csv
# * hydro ch0 file: 20190626_s2_t4_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t4_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 40 ------------
# 20190626_s2_t5
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t5_GOPR1470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t5_dtag.csv
# * hydro ch0 file: 20190626_s2_t5_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t5_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 41 ------------
# 20190626_s2_t6
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t6_GP011470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t6_dtag.csv
# * hydro ch0 file: 20190626_s2_t6_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t6_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 42 ------------
# 20190626_s2_t7
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t7_GP011470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t7_dtag.csv
# * hydro ch0 file: 20190626_s2_t7_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t7_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 43 ------------
# 20190626_s2_t8
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t8_GP011470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t8_dtag.csv
# * hydro ch0 file: 20190626_s2_t8_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t8_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 44 ------------
# 20190626_s2_t9
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t9_GP011470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t9_dtag.csv
# * hydro ch0 file: 20190626_s2_t9_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t9_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 45 ------------
# 20190626_s2_t10
# * cal object selected: hula_noflip
# * track file:     20190626_s2_t10_GP011470_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190626_s2_t10_dtag.csv
# * hydro ch0 file: 20190626_s2_t10_hydro_ch0.csv
# * hydro ch1 file: 20190626_s2_t10_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 46 ------------
# 20190626_s3_t1
# * cal object selected: hula_flip
# * track file:     20190626_s3_t1_GOPR1471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t1_dtag.csv
# * hydro ch0 file: 20190626_s3_t1_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 47 ------------
# 20190626_s3_t2
# * cal object selected: hula_flip
# * track file:     20190626_s3_t2_GOPR1471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t2_dtag.csv
# * hydro ch0 file: 20190626_s3_t2_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t2_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 48 ------------
# 20190626_s3_t3
# * cal object selected: hula_flip
# * track file:     20190626_s3_t3_GP011471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t3_dtag.csv
# * hydro ch0 file: 20190626_s3_t3_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t3_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 49 ------------
# 20190626_s3_t4
# * cal object selected: hula_flip
# * track file:     20190626_s3_t4_GP011471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t4_dtag.csv
# * hydro ch0 file: 20190626_s3_t4_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t4_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 50 ------------
# 20190626_s3_t5
# * cal object selected: hula_flip
# * track file:     20190626_s3_t5_GP011471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t5_dtag.csv
# * hydro ch0 file: 20190626_s3_t5_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t5_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 51 ------------
# 20190626_s3_t6
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 52 ------------
# 20190626_s3_t7
# * cal object selected: hula_flip
# * track file:     20190626_s3_t7_GP011471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t7_dtag.csv
# * hydro ch0 file: 20190626_s3_t7_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t7_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 53 ------------
# 20190626_s3_t8
# * cal object selected: hula_flip
# * track file:     20190626_s3_t8_GP011471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t8_dtag.csv
# * hydro ch0 file: 20190626_s3_t8_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t8_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 54 ------------
# 20190626_s3_t9
# * cal object selected: hula_flip
# * track file:     20190626_s3_t9_GP011471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t9_dtag.csv
# * hydro ch0 file: 20190626_s3_t9_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t9_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 55 ------------
# 20190626_s3_t10
# * cal object selected: hula_flip
# * track file:     20190626_s3_t10_GP011471_xypressure_hula_flip_transformed.csv
# * dtag file:      20190626_s3_t10_dtag.csv
# * hydro ch0 file: 20190626_s3_t10_hydro_ch0.csv
# * hydro ch1 file: 20190626_s3_t10_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 56 ------------
# 20190627_s1_t1
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 57 ------------
# 20190627_s1_t2
# * cal object selected: hula_flip
# * track file:     20190627_s1_t2_GOPR1472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t2_dtag.csv
# * hydro ch0 file: 20190627_s1_t2_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t2_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 58 ------------
# 20190627_s1_t3
# * cal object selected: hula_flip
# * track file:     20190627_s1_t3_GOPR1472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t3_dtag.csv
# * hydro ch0 file: 20190627_s1_t3_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t3_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 59 ------------
# 20190627_s1_t4
# * cal object selected: hula_flip
# * track file:     20190627_s1_t4_GOPR1472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t4_dtag.csv
# * hydro ch0 file: 20190627_s1_t4_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t4_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 60 ------------
# 20190627_s1_t5
# * cal object selected: hula_flip
# * track file:     20190627_s1_t5_GOPR1472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t5_dtag.csv
# * hydro ch0 file: 20190627_s1_t5_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t5_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
# ------ trial 61 ------------
# 20190627_s1_t6
# * cal object selected: hula_flip
# * track file:     20190627_s1_t6_GOPR1472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t6_dtag.csv
# * hydro ch0 file: 20190627_s1_t6_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t6_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 62 ------------
# 20190627_s1_t7
# * cal object selected: hula_flip
# * track file:     20190627_s1_t7_GOPR1472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t7_dtag.csv
# * hydro ch0 file: 20190627_s1_t7_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t7_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 63 ------------
# 20190627_s1_t8
# * cal object selected: hula_flip
# * track file:     20190627_s1_t8_GOPR1472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t8_dtag.csv
# * hydro ch0 file: 20190627_s1_t8_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t8_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 64 ------------
# 20190627_s1_t9
# * cal object selected: hula_flip
# * track file:     20190627_s1_t9_GP011472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t9_dtag.csv
# * hydro ch0 file: 20190627_s1_t9_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t9_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 65 ------------
# 20190627_s1_t10
# * cal object selected: hula_flip
# * track file:     20190627_s1_t10_GP011472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t10_dtag.csv
# * hydro ch0 file: 20190627_s1_t10_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t10_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 66 ------------
# 20190627_s1_t11
# * cal object selected: hula_flip
# * track file:     20190627_s1_t11_GP011472_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s1_t11_dtag.csv
# * hydro ch0 file: 20190627_s1_t11_hydro_ch0.csv
# * hydro ch1 file: 20190627_s1_t11_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 67 ------------
# 20190627_s2_t1
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 68 ------------
# 20190627_s2_t2
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 69 ------------
# 20190627_s2_t3
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 70 ------------
# 20190627_s2_t4
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 71 ------------
# 20190627_s2_t5
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 72 ------------
# 20190627_s2_t6
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 73 ------------
# 20190627_s2_t7
# * cal object selected: hula_flip
# * track file:     20190627_s2_t7_GP011473_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s2_t7_dtag.csv
# * hydro ch0 file: 20190627_s2_t7_hydro_ch0.csv
# * hydro ch1 file: 20190627_s2_t7_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 74 ------------
# 20190627_s2_t8
# * cal object selected: hula_flip
# * track file:     20190627_s2_t8_GP011473_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s2_t8_dtag.csv
# * hydro ch0 file: 20190627_s2_t8_hydro_ch0.csv
# * hydro ch1 file: 20190627_s2_t8_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 75 ------------
# 20190627_s2_t9
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 76 ------------
# 20190627_s2_t10
# Clicks not synced!
# Cannot identify touch frame in this video!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 77 ------------
# 20190627_s2_t11
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 78 ------------
# 20190627_s3_t1
# * cal object selected: hula_flip
# * track file:     20190627_s3_t1_GOPR1474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t1_dtag.csv
# * hydro ch0 file: 20190627_s3_t1_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t1_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 79 ------------
# 20190627_s3_t2
# * cal object selected: hula_flip
# * track file:     20190627_s3_t2_GOPR1474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t2_dtag.csv
# * hydro ch0 file: 20190627_s3_t2_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t2_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 80 ------------
# 20190627_s3_t3
# * cal object selected: hula_flip
# * track file:     20190627_s3_t3_GOPR1474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t3_dtag.csv
# * hydro ch0 file: 20190627_s3_t3_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t3_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 81 ------------
# 20190627_s3_t4
# * cal object selected: hula_flip
# * track file:     20190627_s3_t4_GOPR1474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t4_dtag.csv
# * hydro ch0 file: 20190627_s3_t4_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t4_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 82 ------------
# 20190627_s3_t5
# * cal object selected: hula_flip
# * track file:     20190627_s3_t5_GOPR1474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t5_dtag.csv
# * hydro ch0 file: 20190627_s3_t5_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t5_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 83 ------------
# 20190627_s3_t6
# * cal object selected: hula_flip
# * track file:     20190627_s3_t6_GOPR1474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t6_dtag.csv
# * hydro ch0 file: 20190627_s3_t6_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t6_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 84 ------------
# 20190627_s3_t7
# * cal object selected: hula_flip
# * track file:     20190627_s3_t7_GP011474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t7_dtag.csv
# * hydro ch0 file: 20190627_s3_t7_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t7_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 85 ------------
# 20190627_s3_t8
# * cal object selected: hula_flip
# * track file:     20190627_s3_t8_GP011474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t8_dtag.csv
# * hydro ch0 file: 20190627_s3_t8_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t8_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 86 ------------
# 20190627_s3_t9
# * cal object selected: hula_flip
# * track file:     20190627_s3_t9_GP011474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t9_dtag.csv
# * hydro ch0 file: 20190627_s3_t9_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t9_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 87 ------------
# 20190627_s3_t10
# * cal object selected: hula_flip
# * track file:     20190627_s3_t10_GP011474_xypressure_hula_flip_transformed.csv
# * dtag file:      20190627_s3_t10_dtag.csv
# * hydro ch0 file: 20190627_s3_t10_hydro_ch0.csv
# * hydro ch1 file: 20190627_s3_t10_hydro_ch1.csv
# * scenario: TC3
# * choice: 0
#
# ------ trial 88 ------------
# 20190627_s3_t11
# Some data missing in this trial, skipping...
#
# ------ trial 89 ------------
# 20190628_s1_t1
# * cal object selected: hula_flip
# * track file:     20190628_s1_t1_GOPR1475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t1_dtag.csv
# * hydro ch0 file: 20190628_s1_t1_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t1_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 90 ------------
# 20190628_s1_t2
# * cal object selected: hula_flip
# * track file:     20190628_s1_t2_GOPR1475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t2_dtag.csv
# * hydro ch0 file: 20190628_s1_t2_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t2_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 91 ------------
# 20190628_s1_t3
# * cal object selected: hula_flip
# * track file:     20190628_s1_t3_GOPR1475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t3_dtag.csv
# * hydro ch0 file: 20190628_s1_t3_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t3_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 92 ------------
# 20190628_s1_t4
# * cal object selected: hula_flip
# * track file:     20190628_s1_t4_GOPR1475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t4_dtag.csv
# * hydro ch0 file: 20190628_s1_t4_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t4_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
# ------ trial 93 ------------
# 20190628_s1_t5
# * cal object selected: hula_flip
# * track file:     20190628_s1_t5_GOPR1475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t5_dtag.csv
# * hydro ch0 file: 20190628_s1_t5_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t5_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 94 ------------
# 20190628_s1_t6
# * cal object selected: hula_flip
# * track file:     20190628_s1_t6_GP011475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t6_dtag.csv
# * hydro ch0 file: 20190628_s1_t6_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t6_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 95 ------------
# 20190628_s1_t7
# * cal object selected: hula_flip
# * track file:     20190628_s1_t7_GP011475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t7_dtag.csv
# * hydro ch0 file: 20190628_s1_t7_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t7_hydro_ch1.csv
# * scenario: CT3
# * choice: 0
#
# ------ trial 96 ------------
# 20190628_s1_t8
# * cal object selected: hula_flip
# * track file:     20190628_s1_t8_GP011475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t8_dtag.csv
# * hydro ch0 file: 20190628_s1_t8_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t8_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 97 ------------
# 20190628_s1_t9
# * cal object selected: hula_flip
# * track file:     20190628_s1_t9_GP011475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t9_dtag.csv
# * hydro ch0 file: 20190628_s1_t9_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t9_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 98 ------------
# 20190628_s1_t10
# * cal object selected: hula_flip
# * track file:     20190628_s1_t10_GP011475_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s1_t10_dtag.csv
# * hydro ch0 file: 20190628_s1_t10_hydro_ch0.csv
# * hydro ch1 file: 20190628_s1_t10_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 99 ------------
# 20190628_s2_t1
# * cal object selected: hula_flip
# * track file:     20190628_s2_t1_GOPR1476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t1_dtag.csv
# * hydro ch0 file: 20190628_s2_t1_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 100 ------------
# 20190628_s2_t2
# * cal object selected: hula_flip
# * track file:     20190628_s2_t2_GOPR1476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t2_dtag.csv
# * hydro ch0 file: 20190628_s2_t2_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t2_hydro_ch1.csv
# * scenario: TC1
# * choice: 0
#
# ------ trial 101 ------------
# 20190628_s2_t3
# * cal object selected: hula_flip
# * track file:     20190628_s2_t3_GOPR1476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t3_dtag.csv
# * hydro ch0 file: 20190628_s2_t3_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t3_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 102 ------------
# 20190628_s2_t4
# * cal object selected: hula_flip
# * track file:     20190628_s2_t4_GOPR1476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t4_dtag.csv
# * hydro ch0 file: 20190628_s2_t4_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t4_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 103 ------------
# 20190628_s2_t5
# * cal object selected: hula_flip
# * track file:     20190628_s2_t5_GOPR1476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t5_dtag.csv
# * hydro ch0 file: 20190628_s2_t5_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t5_hydro_ch1.csv
# * scenario: TC1
# * choice: 0
#
# ------ trial 104 ------------
# 20190628_s2_t6
# * cal object selected: hula_flip
# * track file:     20190628_s2_t6_GOPR1476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t6_dtag.csv
# * hydro ch0 file: 20190628_s2_t6_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t6_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 105 ------------
# 20190628_s2_t7
# * cal object selected: hula_flip
# * track file:     20190628_s2_t7_GP011476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t7_dtag.csv
# * hydro ch0 file: 20190628_s2_t7_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t7_hydro_ch1.csv
# * scenario: CT1
# * choice: 0
#
# ------ trial 106 ------------
# 20190628_s2_t8
# * cal object selected: hula_flip
# * track file:     20190628_s2_t8_GP011476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t8_dtag.csv
# * hydro ch0 file: 20190628_s2_t8_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t8_hydro_ch1.csv
# * scenario: TC1
# * choice: 0
#
# ------ trial 107 ------------
# 20190628_s2_t9
# * cal object selected: hula_flip
# * track file:     20190628_s2_t9_GP011476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t9_dtag.csv
# * hydro ch0 file: 20190628_s2_t9_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t9_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 108 ------------
# 20190628_s2_t10
# * cal object selected: hula_flip
# * track file:     20190628_s2_t10_GP011476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t10_dtag.csv
# * hydro ch0 file: 20190628_s2_t10_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t10_hydro_ch1.csv
# * scenario: TC1
# * choice: 0
#
# ------ trial 109 ------------
# 20190628_s2_t11
# * cal object selected: hula_flip
# * track file:     20190628_s2_t11_GP011476_xypressure_hula_flip_transformed.csv
# * dtag file:      20190628_s2_t11_dtag.csv
# * hydro ch0 file: 20190628_s2_t11_hydro_ch0.csv
# * hydro ch1 file: 20190628_s2_t11_hydro_ch1.csv
# * scenario: TC1
# * choice: 0
#
# ------ trial 110 ------------
# 20190628_s2_t12
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 111 ------------
# 20190628_s3_t1
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t1_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t1_dtag.csv
# * hydro ch0 file: 20190628_s3_t1_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 112 ------------
# 20190628_s3_t2
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t2_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t2_dtag.csv
# * hydro ch0 file: 20190628_s3_t2_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t2_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 113 ------------
# 20190628_s3_t3
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t3_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t3_dtag.csv
# * hydro ch0 file: 20190628_s3_t3_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t3_hydro_ch1.csv
# * scenario: CT3
# * choice: 0
#
# ------ trial 114 ------------
# 20190628_s3_t4
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t4_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t4_dtag.csv
# * hydro ch0 file: 20190628_s3_t4_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t4_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 115 ------------
# 20190628_s3_t5
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t5_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t5_dtag.csv
# * hydro ch0 file: 20190628_s3_t5_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t5_hydro_ch1.csv
# * scenario: CT3
# * choice: 0
#
# ------ trial 116 ------------
# 20190628_s3_t6
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t6_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t6_dtag.csv
# * hydro ch0 file: 20190628_s3_t6_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t6_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 117 ------------
# 20190628_s3_t7
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t7_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t7_dtag.csv
# * hydro ch0 file: 20190628_s3_t7_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t7_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 118 ------------
# 20190628_s3_t8
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t8_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t8_dtag.csv
# * hydro ch0 file: 20190628_s3_t8_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t8_hydro_ch1.csv
# * scenario: CT2
# * choice: 0
# ------ trial 119 ------------
# 20190628_s3_t9
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t9_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t9_dtag.csv
# * hydro ch0 file: 20190628_s3_t9_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t9_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 120 ------------
# 20190628_s3_t10
# * cal object selected: hula_noflip
# * track file:     20190628_s3_t10_GOPR1477_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190628_s3_t10_dtag.csv
# * hydro ch0 file: 20190628_s3_t10_hydro_ch0.csv
# * hydro ch1 file: 20190628_s3_t10_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 121 ------------
# 20190701_s1_t1
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t1_GOPR1478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t1_dtag.csv
# * hydro ch0 file: 20190701_s1_t1_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t1_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 122 ------------
# 20190701_s1_t2
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t2_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t2_dtag.csv
# * hydro ch0 file: 20190701_s1_t2_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t2_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 123 ------------
# 20190701_s1_t3
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t3_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t3_dtag.csv
# * hydro ch0 file: 20190701_s1_t3_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t3_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 124 ------------
# 20190701_s1_t4
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t4_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t4_dtag.csv
# * hydro ch0 file: 20190701_s1_t4_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t4_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 125 ------------
# 20190701_s1_t5
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t5_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t5_dtag.csv
# * hydro ch0 file: 20190701_s1_t5_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t5_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 126 ------------
# 20190701_s1_t6
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t6_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t6_dtag.csv
# * hydro ch0 file: 20190701_s1_t6_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t6_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 127 ------------
# 20190701_s1_t7
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t7_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t7_dtag.csv
# * hydro ch0 file: 20190701_s1_t7_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t7_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 128 ------------
# 20190701_s1_t8
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t8_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t8_dtag.csv
# * hydro ch0 file: 20190701_s1_t8_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t8_hydro_ch1.csv
# * scenario: CT1
# * choice: 0
#
# ------ trial 129 ------------
# 20190701_s1_t9
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t9_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t9_dtag.csv
# * hydro ch0 file: 20190701_s1_t9_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t9_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 130 ------------
# 20190701_s1_t10
# * cal object selected: hula_noflip
# * track file:     20190701_s1_t10_GP011478_xypressure_hula_noflip_transformed.csv
# * dtag file:      20190701_s1_t10_dtag.csv
# * hydro ch0 file: 20190701_s1_t10_hydro_ch0.csv
# * hydro ch1 file: 20190701_s1_t10_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 131 ------------
# 20190701_s2_t1
# * cal object selected: hula_flip
# * track file:     20190701_s2_t1_GP011479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t1_dtag.csv
# * hydro ch0 file: 20190701_s2_t1_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 132 ------------
# 20190701_s2_t2
# * cal object selected: hula_flip
# * track file:     20190701_s2_t2_GP011479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t2_dtag.csv
# * hydro ch0 file: 20190701_s2_t2_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t2_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 133 ------------
# 20190701_s2_t3
# * cal object selected: hula_flip
# * track file:     20190701_s2_t3_GP011479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t3_dtag.csv
# * hydro ch0 file: 20190701_s2_t3_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t3_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 134 ------------
# 20190701_s2_t4
# * cal object selected: hula_flip
# * track file:     20190701_s2_t4_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t4_dtag.csv
# * hydro ch0 file: 20190701_s2_t4_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t4_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 135 ------------
# 20190701_s2_t5
# * cal object selected: hula_flip
# * track file:     20190701_s2_t5_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t5_dtag.csv
# * hydro ch0 file: 20190701_s2_t5_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t5_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 136 ------------
# 20190701_s2_t6
# * cal object selected: hula_flip
# * track file:     20190701_s2_t6_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t6_dtag.csv
# * hydro ch0 file: 20190701_s2_t6_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t6_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 137 ------------
# 20190701_s2_t7
# * cal object selected: hula_flip
# * track file:     20190701_s2_t7_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t7_dtag.csv
# * hydro ch0 file: 20190701_s2_t7_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t7_hydro_ch1.csv
# * scenario: CT2
# * choice: 0
#
# ------ trial 138 ------------
# 20190701_s2_t8
# * cal object selected: hula_flip
# * track file:     20190701_s2_t8_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t8_dtag.csv
# * hydro ch0 file: 20190701_s2_t8_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t8_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 139 ------------
# 20190701_s2_t9
# * cal object selected: hula_flip
# * track file:     20190701_s2_t9_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t9_dtag.csv
# * hydro ch0 file: 20190701_s2_t9_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t9_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 140 ------------
# 20190701_s2_t10
# * cal object selected: hula_flip
# * track file:     20190701_s2_t10_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t10_dtag.csv
# * hydro ch0 file: 20190701_s2_t10_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t10_hydro_ch1.csv
# * scenario: CT3
# * choice: 0
#
# ------ trial 141 ------------
# 20190701_s2_t11
# * cal object selected: hula_flip
# * track file:     20190701_s2_t11_GP021479_xypressure_hula_flip_transformed.csv
# * dtag file:      20190701_s2_t11_dtag.csv
# * hydro ch0 file: 20190701_s2_t11_hydro_ch0.csv
# * hydro ch1 file: 20190701_s2_t11_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 142 ------------
# 20190701_s3_t1
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 143 ------------
# 20190701_s3_t2
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 144 ------------
# 20190701_s3_t3
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 145 ------------
# 20190701_s3_t4
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 146 ------------
# 20190701_s3_t5
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 147 ------------
# 20190701_s3_t6
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 148 ------------
# 20190701_s3_t7
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 149 ------------
# 20190701_s3_t8
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 150 ------------
# 20190701_s3_t9
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 151 ------------
# 20190701_s3_t10
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 152 ------------
# 20190702_s1_t1
# * cal object selected: cross
# * track file:     20190702_s1_t1_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t1_dtag.csv
# * hydro ch0 file: 20190702_s1_t1_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t1_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
# ------ trial 153 ------------
# 20190702_s1_t2
# * cal object selected: cross
# * track file:     20190702_s1_t2_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t2_dtag.csv
# * hydro ch0 file: 20190702_s1_t2_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t2_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 154 ------------
# 20190702_s1_t3
# * cal object selected: cross
# * track file:     20190702_s1_t3_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t3_dtag.csv
# * hydro ch0 file: 20190702_s1_t3_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t3_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 155 ------------
# 20190702_s1_t4
# * cal object selected: cross
# * track file:     20190702_s1_t4_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t4_dtag.csv
# * hydro ch0 file: 20190702_s1_t4_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t4_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 156 ------------
# 20190702_s1_t5
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 157 ------------
# 20190702_s1_t6
# * cal object selected: cross
# * track file:     20190702_s1_t6_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t6_dtag.csv
# * hydro ch0 file: 20190702_s1_t6_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t6_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 158 ------------
# 20190702_s1_t7
# * cal object selected: cross
# * track file:     20190702_s1_t7_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t7_dtag.csv
# * hydro ch0 file: 20190702_s1_t7_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t7_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 159 ------------
# 20190702_s1_t8
# * cal object selected: cross
# * track file:     20190702_s1_t8_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t8_dtag.csv
# * hydro ch0 file: 20190702_s1_t8_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t8_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 160 ------------
# 20190702_s1_t9
# * cal object selected: cross
# * track file:     20190702_s1_t9_GOPR1481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t9_dtag.csv
# * hydro ch0 file: 20190702_s1_t9_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t9_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 161 ------------
# 20190702_s1_t10
# * cal object selected: cross
# * track file:     20190702_s1_t10_GP011481_xypressure_cross_transformed.csv
# * dtag file:      20190702_s1_t10_dtag.csv
# * hydro ch0 file: 20190702_s1_t10_hydro_ch0.csv
# * hydro ch1 file: 20190702_s1_t10_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 162 ------------
# 20190702_s2_t1
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 163 ------------
# 20190702_s2_t2
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 164 ------------
# 20190702_s2_t3
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 165 ------------
# 20190702_s2_t4
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 166 ------------
# 20190702_s2_t5
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 167 ------------
# 20190702_s2_t6
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 168 ------------
# 20190702_s2_t7
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 169 ------------
# 20190702_s2_t8
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 170 ------------
# 20190702_s2_t9
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 171 ------------
# 20190702_s2_t10
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 172 ------------
# 20190702_s2_t11
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 173 ------------
# 20190702_s3_t1
# * cal object selected: cross
# * track file:     20190702_s3_t1_GOPR1483_xypressure_cross_transformed.csv
# * dtag file:      20190702_s3_t1_dtag.csv
# * hydro ch0 file: 20190702_s3_t1_hydro_ch0.csv
# * hydro ch1 file: 20190702_s3_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 174 ------------
# 20190702_s3_t2
# * cal object selected: cross
# * track file:     20190702_s3_t2_GOPR1483_xypressure_cross_transformed.csv
# * dtag file:      20190702_s3_t2_dtag.csv
# * hydro ch0 file: 20190702_s3_t2_hydro_ch0.csv
# * hydro ch1 file: 20190702_s3_t2_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 175 ------------
# 20190702_s3_t3
# * cal object selected: cross
# * track file:     20190702_s3_t3_GOPR1483_xypressure_cross_transformed.csv
# * dtag file:      20190702_s3_t3_dtag.csv
# * hydro ch0 file: 20190702_s3_t3_hydro_ch0.csv
# * hydro ch1 file: 20190702_s3_t3_hydro_ch1.csv
# * scenario: CT3
# * choice: 0
#
# ------ trial 176 ------------
# 20190702_s3_t4
# * cal object selected: cross
# * track file:     20190702_s3_t4_GOPR1483_xypressure_cross_transformed.csv
# * dtag file:      20190702_s3_t4_dtag.csv
# ...
# 20190703_s2_t3
# * cal object selected: cross
# * track file:     20190703_s2_t3_GOPR1485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t3_dtag.csv
# * hydro ch0 file: 20190703_s2_t3_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t3_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 196 ------------
# 20190703_s2_t4
# * cal object selected: cross
# * track file:     20190703_s2_t4_GOPR1485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t4_dtag.csv
# * hydro ch0 file: 20190703_s2_t4_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t4_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 197 ------------
# 20190703_s2_t5
# * cal object selected: cross
# * track file:     20190703_s2_t5_GOPR1485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t5_dtag.csv
# * hydro ch0 file: 20190703_s2_t5_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t5_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 198 ------------
# 20190703_s2_t6
# * cal object selected: cross
# * track file:     20190703_s2_t6_GOPR1485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t6_dtag.csv
# * hydro ch0 file: 20190703_s2_t6_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t6_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 199 ------------
# 20190703_s2_t7
# * cal object selected: cross
# * track file:     20190703_s2_t7_GP011485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t7_dtag.csv
# * hydro ch0 file: 20190703_s2_t7_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t7_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 200 ------------
# 20190703_s2_t8
# * cal object selected: cross
# * track file:     20190703_s2_t8_GP011485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t8_dtag.csv
# * hydro ch0 file: 20190703_s2_t8_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t8_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 201 ------------
# 20190703_s2_t9
# * cal object selected: cross
# * track file:     20190703_s2_t9_GP011485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t9_dtag.csv
# * hydro ch0 file: 20190703_s2_t9_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t9_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 202 ------------
# 20190703_s2_t10
# * cal object selected: cross
# * track file:     20190703_s2_t10_GP011485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t10_dtag.csv
# * hydro ch0 file: 20190703_s2_t10_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t10_hydro_ch1.csv
# * scenario: CT1
# * choice: 0
#
# ------ trial 203 ------------
# 20190703_s2_t11
# * cal object selected: cross
# * track file:     20190703_s2_t11_GP011485_xypressure_cross_transformed.csv
# * dtag file:      20190703_s2_t11_dtag.csv
# * hydro ch0 file: 20190703_s2_t11_hydro_ch0.csv
# * hydro ch1 file: 20190703_s2_t11_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 204 ------------
# 20190703_s3_t1
# * cal object selected: cross
# * track file:     20190703_s3_t1_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t1_dtag.csv
# * hydro ch0 file: 20190703_s3_t1_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t1_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 205 ------------
# 20190703_s3_t2
# * cal object selected: cross
# * track file:     20190703_s3_t2_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t2_dtag.csv
# * hydro ch0 file: 20190703_s3_t2_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t2_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 206 ------------
# 20190703_s3_t3
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 207 ------------
# 20190703_s3_t4
# * cal object selected: cross
# * track file:     20190703_s3_t4_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t4_dtag.csv
# * hydro ch0 file: 20190703_s3_t4_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t4_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 208 ------------
# 20190703_s3_t5
# Clicks not synced!
# No track file!
# No target file!
# Some data missing in this trial, skipping...
#
# ------ trial 209 ------------
# 20190703_s3_t6
# * cal object selected: cross
# * track file:     20190703_s3_t6_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t6_dtag.csv
# * hydro ch0 file: 20190703_s3_t6_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t6_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 210 ------------
# 20190703_s3_t7
# * cal object selected: cross
# * track file:     20190703_s3_t7_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t7_dtag.csv
# * hydro ch0 file: 20190703_s3_t7_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t7_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 211 ------------
# 20190703_s3_t8
# * cal object selected: cross
# * track file:     20190703_s3_t8_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t8_dtag.csv
# * hydro ch0 file: 20190703_s3_t8_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t8_hydro_ch1.csv
# * scenario: CT2
# * choice: 0
#
# ------ trial 212 ------------
# 20190703_s3_t9
# * cal object selected: cross
# * track file:     20190703_s3_t9_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t9_dtag.csv
# * hydro ch0 file: 20190703_s3_t9_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t9_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 213 ------------
# 20190703_s3_t10
# * cal object selected: cross
# * track file:     20190703_s3_t10_GOPR1486_xypressure_cross_transformed.csv
# * dtag file:      20190703_s3_t10_dtag.csv
# * hydro ch0 file: 20190703_s3_t10_hydro_ch0.csv
# * hydro ch1 file: 20190703_s3_t10_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 214 ------------
# 20190704_s1_t1
# * cal object selected: cross
# * track file:     20190704_s1_t1_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t1_dtag.csv
# * hydro ch0 file: 20190704_s1_t1_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
# ------ trial 215 ------------
# 20190704_s1_t2
# * cal object selected: cross
# * track file:     20190704_s1_t2_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t2_dtag.csv
# * hydro ch0 file: 20190704_s1_t2_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t2_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 216 ------------
# 20190704_s1_t3
# * cal object selected: cross
# * track file:     20190704_s1_t3_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t3_dtag.csv
# * hydro ch0 file: 20190704_s1_t3_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t3_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 217 ------------
# 20190704_s1_t4
# * cal object selected: cross
# * track file:     20190704_s1_t4_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t4_dtag.csv
# * hydro ch0 file: 20190704_s1_t4_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t4_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 218 ------------
# 20190704_s1_t5
# * cal object selected: cross
# * track file:     20190704_s1_t5_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t5_dtag.csv
# * hydro ch0 file: 20190704_s1_t5_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t5_hydro_ch1.csv
# * scenario: TC3
# * choice: 1
#
# ------ trial 219 ------------
# 20190704_s1_t6
# * cal object selected: cross
# * track file:     20190704_s1_t6_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t6_dtag.csv
# * hydro ch0 file: 20190704_s1_t6_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t6_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 220 ------------
# 20190704_s1_t7
# * cal object selected: cross
# * track file:     20190704_s1_t7_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t7_dtag.csv
# * hydro ch0 file: 20190704_s1_t7_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t7_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 221 ------------
# 20190704_s1_t8
# * cal object selected: cross
# * track file:     20190704_s1_t8_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t8_dtag.csv
# * hydro ch0 file: 20190704_s1_t8_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t8_hydro_ch1.csv
# * scenario: TC2
# * choice: 1
#
# ------ trial 222 ------------
# 20190704_s1_t9
# * cal object selected: cross
# * track file:     20190704_s1_t9_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t9_dtag.csv
# * hydro ch0 file: 20190704_s1_t9_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t9_hydro_ch1.csv
# * scenario: CT4
# * choice: 1
#
# ------ trial 223 ------------
# 20190704_s1_t10
# * cal object selected: cross
# * track file:     20190704_s1_t10_GOPR1487_xypressure_cross_transformed.csv
# * dtag file:      20190704_s1_t10_dtag.csv
# * hydro ch0 file: 20190704_s1_t10_hydro_ch0.csv
# * hydro ch1 file: 20190704_s1_t10_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 224 ------------
# 20190704_s2_t1
# * cal object selected: cross
# * track file:     20190704_s2_t1_GOPR1488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t1_dtag.csv
# * hydro ch0 file: 20190704_s2_t1_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t1_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 225 ------------
# 20190704_s2_t2
# * cal object selected: cross
# * track file:     20190704_s2_t2_GOPR1488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t2_dtag.csv
# * hydro ch0 file: 20190704_s2_t2_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t2_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 226 ------------
# 20190704_s2_t3
# * cal object selected: cross
# * track file:     20190704_s2_t3_GOPR1488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t3_dtag.csv
# * hydro ch0 file: 20190704_s2_t3_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t3_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 227 ------------
# 20190704_s2_t4
# * cal object selected: cross
# * track file:     20190704_s2_t4_GOPR1488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t4_dtag.csv
# * hydro ch0 file: 20190704_s2_t4_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t4_hydro_ch1.csv
# * scenario: CT1
# * choice: 0
#
# ------ trial 228 ------------
# 20190704_s2_t5
# * cal object selected: cross
# * track file:     20190704_s2_t5_GOPR1488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t5_dtag.csv
# * hydro ch0 file: 20190704_s2_t5_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t5_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 229 ------------
# 20190704_s2_t6
# * cal object selected: cross
# * track file:     20190704_s2_t6_GOPR1488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t6_dtag.csv
# * hydro ch0 file: 20190704_s2_t6_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t6_hydro_ch1.csv
# * scenario: CT1
# * choice: 0
#
# ------ trial 230 ------------
# 20190704_s2_t7
# * cal object selected: cross
# * track file:     20190704_s2_t7_GOPR1488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t7_dtag.csv
# * hydro ch0 file: 20190704_s2_t7_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t7_hydro_ch1.csv
# * scenario: CT1
# * choice: 0
#
# ------ trial 231 ------------
# 20190704_s2_t8
# * cal object selected: cross
# * track file:     20190704_s2_t8_GP011488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t8_dtag.csv
# * hydro ch0 file: 20190704_s2_t8_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t8_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 232 ------------
# 20190704_s2_t9
# * cal object selected: cross
# * track file:     20190704_s2_t9_GP011488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t9_dtag.csv
# * hydro ch0 file: 20190704_s2_t9_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t9_hydro_ch1.csv
# * scenario: CT1
# * choice: 1
#
# ------ trial 233 ------------
# 20190704_s2_t10
# * cal object selected: cross
# * track file:     20190704_s2_t10_GP011488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t10_dtag.csv
# * hydro ch0 file: 20190704_s2_t10_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t10_hydro_ch1.csv
# * scenario: TC1
# * choice: 0
#
# ------ trial 234 ------------
# 20190704_s2_t11
# * cal object selected: cross
# * track file:     20190704_s2_t11_GP011488_xypressure_cross_transformed.csv
# * dtag file:      20190704_s2_t11_dtag.csv
# * hydro ch0 file: 20190704_s2_t11_hydro_ch0.csv
# * hydro ch1 file: 20190704_s2_t11_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 235 ------------
# 20190704_s3_t1
# * cal object selected: cross
# * track file:     20190704_s3_t1_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t1_dtag.csv
# * hydro ch0 file: 20190704_s3_t1_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t1_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 236 ------------
# 20190704_s3_t2
# * cal object selected: cross
# * track file:     20190704_s3_t2_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t2_dtag.csv
# * hydro ch0 file: 20190704_s3_t2_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t2_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 237 ------------
# 20190704_s3_t3
# * cal object selected: cross
# * track file:     20190704_s3_t3_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t3_dtag.csv
# * hydro ch0 file: 20190704_s3_t3_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t3_hydro_ch1.csv
# * scenario: CT2
# * choice: 1
#
# ------ trial 238 ------------
# 20190704_s3_t4
# * cal object selected: cross
# * track file:     20190704_s3_t4_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t4_dtag.csv
# * hydro ch0 file: 20190704_s3_t4_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t4_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 239 ------------
# 20190704_s3_t5
# * cal object selected: cross
# * track file:     20190704_s3_t5_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t5_dtag.csv
# * hydro ch0 file: 20190704_s3_t5_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t5_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 240 ------------
# 20190704_s3_t6
# * cal object selected: cross
# * track file:     20190704_s3_t6_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t6_dtag.csv
# * hydro ch0 file: 20190704_s3_t6_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t6_hydro_ch1.csv
# * scenario: TC4
# * choice: 1
#
# ------ trial 241 ------------
# 20190704_s3_t7
# * cal object selected: cross
# * track file:     20190704_s3_t7_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t7_dtag.csv
# * hydro ch0 file: 20190704_s3_t7_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t7_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
# ------ trial 242 ------------
# 20190704_s3_t8
# * cal object selected: cross
# * track file:     20190704_s3_t8_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t8_dtag.csv
# * hydro ch0 file: 20190704_s3_t8_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t8_hydro_ch1.csv
# * scenario: TC1
# * choice: 1
#
# ------ trial 243 ------------
# 20190704_s3_t9
# * cal object selected: cross
# * track file:     20190704_s3_t9_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t9_dtag.csv
# * hydro ch0 file: 20190704_s3_t9_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t9_hydro_ch1.csv
# * scenario: CT3
# * choice: 1
#
# ------ trial 244 ------------
# 20190704_s3_t10
# * cal object selected: cross
# * track file:     20190704_s3_t10_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t10_dtag.csv
# * hydro ch0 file: 20190704_s3_t10_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t10_hydro_ch1.csv
# * scenario: TC3
# * choice: 0
#
# ------ trial 245 ------------
# 20190704_s3_t11
# * cal object selected: cross
# * track file:     20190704_s3_t11_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t11_dtag.csv
# * hydro ch0 file: 20190704_s3_t11_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t11_hydro_ch1.csv
# * scenario: TC3
# * choice: 0
#
# ------ trial 246 ------------
# 20190704_s3_t12
# * cal object selected: cross
# * track file:     20190704_s3_t12_GOPR1489_xypressure_cross_transformed.csv
# * dtag file:      20190704_s3_t12_dtag.csv
# * hydro ch0 file: 20190704_s3_t12_hydro_ch0.csv
# * hydro ch1 file: 20190704_s3_t12_hydro_ch1.csv
# * scenario: TC4
# * choice: 1

# %% [markdown]
# ## Organize dataframe

# %%
df_scan_all = pd.DataFrame(scan_num_all, columns=SCAN_FIELDS)
df_time_all = pd.DataFrame(time_all, columns=TIME_FIELDS)
df_range_all = pd.DataFrame(range_all, columns=RANGE_FIELDS)
df_angle_all = pd.DataFrame(angle_all, columns=ANGLE_FIELDS)

# %%
df_merge_all = pd.concat((df_scan_all, df_time_all, df_range_all, df_angle_all), axis=1)

# %%
df_merge_all[["SPHEROID", "CHOICE", "TARGET_ANGLE", "fname_prefix"]] = df_main[
    ["SPHEROID", "CHOICE", "TARGET_ANGLE", "fname_prefix"]
]

# %%
df_merge_all
# Out:
#      scan_ch0  scan_ch1  scan_combined  time_decision  time_buzz_onset_dtag  \
# 0         NaN       NaN            NaN            NaN                   NaN
# 1         NaN       NaN            NaN            NaN                   NaN
# 2         7.0       7.0           13.0     530.550648            531.263587
# 3         5.0       5.0            9.0     676.986342            677.812622
# 4         7.0       6.0           11.0     764.885338            766.960336
# ..        ...       ...            ...            ...                   ...
# 242       6.0       5.0            9.0     771.450836            772.415519
# 243       7.0       6.0           10.0     830.557031            830.896123
# 244       4.0       4.0            7.0     884.984590            885.468077
# 245       4.0       4.0            7.0     932.993872            934.163839
# 246       5.0       5.0            9.0    1060.670716           1061.454570
#
#      time_buzz_onset_hydro   time_touch  time_last_nonchosen  \
# 0                      NaN          NaN                  NaN
# 1                      NaN          NaN                  NaN
# 2               531.266230   532.564810             0.268760
# 3               677.813616   679.845126             0.304592
# 4               766.961776   768.832284             0.366148
# ..                     ...          ...                  ...
# 242             772.453444   774.404724             0.423488
# 243             830.894679   832.663858             0.356172
# 244             885.475970   887.818785             1.071250
# 245             934.192478   937.301557             0.572210
# 246            1061.452974  1063.228712             0.344862
#
#      range_decision_tar  range_buzz_onset_dtag_tar  ...  range_decision_clu  \
# 0                   NaN                        NaN  ...                 NaN
# 1                   NaN                        NaN  ...                 NaN
# 2              1.083544                   0.718888  ...            1.555132
# 3              1.252419                   0.793524  ...            1.352446
# 4              2.510579                   0.984719  ...            2.441380
# ..                  ...                        ...  ...                 ...
# 242            1.811494                   1.017214  ...            1.461558
# 243            1.222779                   0.956701  ...            1.062928
# 244            1.145556                   1.003286  ...            1.379984
# 245            2.020452                   1.198936  ...            1.929837
# 246            1.774109                   1.035062  ...            1.526640
#
#      range_buzz_onset_dtag_clu  range_buzz_onset_hydro_clu  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                     1.422822                    1.421993
# 3                     0.930691                    0.930646
# 4                     1.450829                    1.450659
# ..                         ...                         ...
# 242                   1.142615                    1.141121
# 243                   0.852896                    0.853144
# 244                   1.042868                    1.039515
# 245                   1.033472                    1.008076
# 246                   1.289893                    1.289827
#
#      angle_range_target  angle_range_clutter  angle_last_scan  SPHEROID  \
# 0                   NaN                  NaN              NaN         X
# 1                   NaN                  NaN              NaN         X
# 2             17.458140            54.204238         5.168805         L
# 3             16.727133             7.348420         1.777283         L
# 4              5.177008            11.058150         1.648957         L
# ..                  ...                  ...              ...       ...
# 242           22.621670             8.123448         7.569817         M
# 243           26.562826             3.005599         0.876847         M
# 244            6.361237            16.815334         1.342138         M
# 245           13.854835             5.841551         4.376336         M
# 246           17.099647            13.009953         8.613763         M
#
#     CHOICE  TARGET_ANGLE     fname_prefix
# 0       -1           TX1   20190625_s1_t0
# 1       -1           TX1   20190625_s1_t0
# 2        1           TC1   20190625_s1_t1
# 3        1           CT1   20190625_s1_t2
# 4        1           TC1   20190625_s1_t3
# ..     ...           ...              ...
# 242      1           TC1   20190704_s3_t8
# 243      1           CT3   20190704_s3_t9
# 244      0           TC3  20190704_s3_t10
# 245      0           TC3  20190704_s3_t11
# 246      1           TC4  20190704_s3_t12
#
# [247 rows x 21 columns]

# %% [markdown]
# ### Select which buzz to use

# %%
def clean_buzz(x, clean_type):
    # For trials in 20190618_s1, use hydro buzz onset
    if x.name >=89 and x.name <=98:
        if clean_type == "time":
            return x["time_buzz_onset_hydro"]
        elif clean_type == "range_target":
            return x["range_buzz_onset_hydro_tar"]
        elif clean_type == "range_clutter":
            return x["range_buzz_onset_hydro_clu"]
        else:
            raise ValueError("Provided type is not supported!")
    
    # For all other trials: use whichever earlier
    if x["time_buzz_onset_hydro"] < x["time_buzz_onset_dtag"]:
        if clean_type == "time":
            return x["time_buzz_onset_hydro"]
        elif clean_type == "range_target":
            return x["range_buzz_onset_hydro_tar"]
        elif clean_type == "range_clutter":
            return x["range_buzz_onset_hydro_clu"]
        else:
            raise ValueError("Provided type is not supported!")
    else:
        if clean_type == "time":
            return x["time_buzz_onset_dtag"]
        elif clean_type == "range_target":
            return x["range_buzz_onset_dtag_tar"]
        elif clean_type == "range_clutter":
            return x["range_buzz_onset_dtag_clu"]
        else:
            raise ValueError("Provided type is not supported!")

# %%
df_merge_all["time_buzz_onset_clean"] = df_merge_all.apply(clean_buzz, clean_type="time", axis=1)

# %%
df_merge_all["time_decision2touch"] = df_merge_all["time_touch"] - df_merge_all["time_decision"]
df_merge_all["time_buzz2touch"] = df_merge_all["time_touch"] - df_merge_all["time_buzz_onset_clean"]

# %%
df_merge_all["range_buzz_onset_tar_clean"] = df_merge_all.apply(clean_buzz, clean_type="range_target", axis=1)
df_merge_all["range_buzz_onset_clu_clean"] = df_merge_all.apply(clean_buzz, clean_type="range_clutter", axis=1)

# %%
def clean_range_buzz_onset(x):
    if x["time_decision2touch"] < x["time_buzz2touch"]:
        # Decision AFTER buzz onset (buzzing at clutter first)
        return x["range_buzz_onset_clu_clean"]
    else:
        # Decision BEFORE buzz onset (buzzing at the target)
        return x["range_buzz_onset_tar_clean"]

# %%
df_merge_all["range_buzz_onset_closest"] = df_merge_all.apply(
    clean_range_buzz_onset, axis=1
)

# %% [markdown]
# ### Export to CSV

# %%
# summary
df_merge_all.to_csv(output_path / "data_summary_all.csv")

# full tracks
with open(output_path / "track_all.pickle", "wb") as fileout:
    pickle.dump(df_track_all, fileout)

# track portions used for clustering
with open(output_path / "track_portion_all.pickle", "wb") as fileout:
    pickle.dump(df_track_portion_all, fileout)
