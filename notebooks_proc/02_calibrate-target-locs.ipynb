# %% [markdown]
# # Calibrate all target locations

# %% [markdown]
# This notebook:
# - calibrates all target locations and save calibrated target locations to `'data_processed/tracks/targets_cal/'`
# - generates `main_info_append_02.csv`

# %%
from pathlib import Path
import pandas as pd

from pp_utils.video_projection import video_projection

# %% [markdown]
# ## Initialize a `video_projection` object

# %%
projection_path = Path('../pp_utils/point_projections/data')

# %%
intrisinc_path = str(projection_path.joinpath('intrinsic_calibration'))
extrinsic_path = str(projection_path.joinpath('extrinsic_calibration'))

vp = video_projection(intrisinc_path=intrisinc_path, extrinsic_path=extrinsic_path)

# %% [markdown]
# ## Load cal object info

# %%
cal_obj_file = projection_path / 'list_calibration_clips.xlsx'
df_cal = pd.read_excel(cal_obj_file)

# %%
df_cal
# Out:
#         DATE  SESSION     VIDEO FRAME_START FRAME_END CAL_OBJECT  \
# 0   20190625        1  GP011466        9356     10533       hula
# 1   20190625        2  GP011467        4053      4752       hula
# 2   20190625        3        --          --        --         --
# 3   20190626        1  GOPR1469       30132     30959       hula
# 4   20190626        2  GP011470       12382     13135       hula
# 5   20190626        3  GP011471       15043     15616       hula
# 6   20190627        1  GP011472        9936     10594       hula
# 7   20190627        2  GP011473       24941     25606       hula
# 8   20190627        3  GP011474       14227     14755       hula
# 9   20190628        1  GP011475       10745     11214       hula
# 10  20190628        2  GP011476       14363     14879       hula
# 11  20190628        3  GP011477           0       504       hula
# 12  20190701        1  GP011478       18300     18636       hula
# 13  20190701        2  GP021479       16410     16747       hula
# 14  20190701        3  GP011480          37       201      cross
# 15  20190702        1  GP011481        4860      5678       hula
# 16  20190702        1  GP011481        6420      8127      cross
# 17  20190702        2  GP011482        5700      6511       hula
# 18  20190702        2  GP011482        7316      7890      cross
# 19  20190702        3  GP011483        4920      5963       hula
# 20  20190702        3  GP011483        6539      7195      cross
# 21  20190703        1  GOPR1484       29398     30192       hula
# 22  20190703        1  GOPR1484       30760     31049      cross
# 23  20190703        2  GP011485       10558     11382       hula
# 24  20190703        2  GP011485       12042     12404      cross
# 25  20190703        3  GOPR1486       29744     30551       hula
# 26  20190703        3  GOPR1486       31250     31424      cross
# 27  20190704        1  GOPR1487       30239     30943       hula
# 28  20190704        1  GP011487           0       477      cross
# 29  20190704        2  GP011488        9243      9978       hula
# 30  20190704        2  GP011488       11153     11904      cross
# 31  20190704        3  GP011489        3480      4283       hula
# 32  20190704        3  GP011489        4822      5236      cross
#
#                                        CAL_VIDEO_PATH  \
# 0   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 1   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 2                                                  --
# 3   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 4   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 5   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 6   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 7   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 8   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 9   /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 10  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 11  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 12  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 13  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 14  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 15  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 16  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 17  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 18  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 19  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 20  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 21  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 22  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 23  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 24  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 25  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 26  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 27  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 28  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 29  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 30  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 31  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
# 32  /Volumes/MURI_4TB/clutter_infotaxis_analysis/v...
#
#                             CAL_VIDEO_FILENAME HULA_HOOP_FLIPPED  \
# 0     20190625_s1_GP011466_9356_10533_hula.mp4                 Y
# 1      20190625_s2_GP011467_4053_4752_hula.mp4                 Y
# 2                                           --                --
# 3    20190626_s1_GOPR1469_30132_30959_hula.mp4                 Y
# 4    20190626_s2_GP011470_12382_13135_hula.mp4                 N
# 5    20190626_s3_GP011471_15043_15616_hula.mp4                 Y
# 6     20190627_s1_GP011472_9936_10594_hula.mp4                 Y
# 7    20190627_s2_GP011473_24941_25606_hula.mp4                 Y
# 8    20190627_s3_GP011474_14227_14755_hula.mp4                 Y
# 9    20190628_s1_GP011475_10745_11214_hula.mp4                 Y
# 10   20190628_s2_GP011476_14363_14879_hula.mp4                 Y
# 11         20190628_s3_GP011477_0_504_hula.mp4                 N
# 12   20190701_s1_GP011478_18300_18636_hula.mp4                 N
# 13   20190701_s2_GP021479_16410_16747_hula.mp4                 Y
# 14       20190701_s3_GP011480_37_201_cross.mp4               NaN
# 15     20190702_s1_GP011481_4860_5678_hula.mp4                 Y
# 16    20190702_s1_GP011481_6420_8127_cross.mp4               NaN
# 17     20190702_s2_GP011482_5700_6511_hula.mp4                 Y
# 18    20190702_s2_GP011482_7316_7890_cross.mp4               NaN
# 19     20190702_s3_GP011483_4920_5963_hula.mp4                 N
# 20    20190702_s3_GP011483_6539_7195_cross.mp4               NaN
# 21   20190703_s1_GOPR1484_29398_30192_hula.mp4                 N
# 22  20190703_s1_GOPR1484_30760_31049_cross.mp4               NaN
# 23   20190703_s2_GP011485_10558_11382_hula.mp4                 N
# 24  20190703_s2_GP011485_12042_12404_cross.mp4               NaN
# 25   20190703_s3_GOPR1486_29744_30551_hula.mp4                 N
# 26  20190703_s3_GOPR1486_31250_31424_cross.mp4               NaN
# 27   20190704_s1_GOPR1487_30239_30943_hula.mp4                 N
# 28        20190704_s1_GP011487_0_477_cross.mp4               NaN
# 29     20190704_s2_GP011488_9243_9978_hula.mp4                 N
# 30  20190704_s2_GP011488_11153_11904_cross.mp4               NaN
# 31     20190704_s3_GP011489_3480_4283_hula.mp4                 Y
# 32    20190704_s3_GP011489_4822_5236_cross.mp4               NaN
#
#    HULA_HOOP_POINTS FRAME_MARKED FRAME_EXTRACTED SIDEDNESS_CHECKED  \
# 0        1,4,6,8,10          432               Y                 Y
# 1        1,4,6,8,10          325               Y                 Y
# 2                --           --              --                --
# 3        1,4,6,8,10          436               Y                 Y
# 4        1,4,6,8,10          376               Y                 Y
# 5        1,4,6,8,10          304               Y                 Y
# 6        1,4,6,8,10          344               Y                 Y
# 7      1,2,4,6,8,10          292               Y                 Y
# 8      1,2,4,6,8,10          285               Y                 Y
# 9      1,2,4,6,8,10          213               Y                 Y
# 10     1,2,4,6,8,10          224               Y                 Y
# 11     1,2,4,6,8,10          201               Y                 Y
# 12     1,2,4,6,8,10          135               Y                 Y
# 13              all          114               Y                 Y
# 14              NaN           41             NaN               NaN
# 15              all          335               Y                 Y
# 16              NaN          308             NaN               NaN
# 17              all          485               Y                 Y
# 18              NaN          272             NaN               NaN
# 19              all          501               Y                 Y
# 20              NaN          300             NaN               NaN
# 21              all          425               Y                 Y
# 22              NaN          109             NaN               NaN
# 23              all          422               Y                 Y
# 24              NaN          151             NaN               NaN
# 25              all          451               Y                 Y
# 26              NaN           20             NaN               NaN
# 27              all          421               Y                 Y
# 28              NaN           64             NaN               NaN
# 29              all          287               Y                 Y
# 30              NaN          341             NaN               NaN
# 31              all          401               Y                 Y
# 32              NaN            1             NaN               NaN
#
#               COMMENTS
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17  camera tilt large?
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27   camera tilt large
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN

# %% [markdown]
# ## Load main data frame: the updated one

# %%
analysis_path = Path('../data_processed/')

# %%
df_main = pd.read_csv(
    analysis_path.joinpath('all_info_csv/main_info_append_01.csv'), index_col=0
)

# %% [markdown]
# ## Load target locations

# %%
targets_file = analysis_path.joinpath('tracks/targets.csv')
df_targets = pd.read_csv(targets_file, index_col=0)

# %%
df_targets
# Out:
#          DATE  SESSION  TRIAL                TARGETS_CSV_FILENAME  \
# 2    20190625        1      1  GOPR1466_20190625_s1_t01_xypts.csv
# 3    20190625        1      2  GOPR1466_20190625_s1_t02_xypts.csv
# 4    20190625        1      3  GOPR1466_20190625_s1_t03_xypts.csv
# 5    20190625        1      4  GOPR1466_20190625_s1_t04_xypts.csv
# 6    20190625        1      5  GOPR1466_20190625_s1_t05_xypts.csv
# ..        ...      ...    ...                                 ...
# 242  20190704        3      8  GOPR1489_20190704_s3_t08_xypts.csv
# 243  20190704        3      9  GOPR1489_20190704_s3_t09_xypts.csv
# 244  20190704        3     10  GOPR1489_20190704_s3_t10_xypts.csv
# 245  20190704        3     11  GOPR1489_20190704_s3_t11_xypts.csv
# 246  20190704        3     12  GOPR1489_20190704_s3_t12_xypts.csv
#
#      TOP_OBJECT_X  TOP_OBJECT_Y  TOP_OBJECT_Z  BOTTOM_OBJECT_X  \
# 2      302.271569    392.854390          -1.0       318.947747
# 3      316.677377    402.137785          -1.0       315.380141
# 4      315.938432    394.360814          -1.0       311.760141
# 5      314.866282    410.306210          -1.0       313.730960
# 6      309.969216    408.364026          -1.0       308.327401
# ..            ...           ...           ...              ...
# 242    291.627729    390.261163          -1.0       288.263092
# 243    269.550265    409.937901          -1.0       272.012987
# 244    265.892256    414.520343          -1.0       265.892256
# 245    266.569745    413.912206          -1.0       268.569745
# 246    272.038961    388.965739          -1.0       270.844877
#
#      BOTTOM_OBJECT_Y  BOTTOM_OBJECT_Z
# 2         644.229963             -1.0
# 3         623.033970             -1.0
# 4         644.245539             -1.0
# 5         647.654532             -1.0
# 6         642.710921             -1.0
# ..               ...              ...
# 242       630.648188             -1.0
# 243       652.507495             -1.0
# 244       657.089936             -1.0
# 245       654.426124             -1.0
# 246       631.535332             -1.0
#
# [235 rows x 10 columns]

# %%
df_targets.columns[4:]
# Out:
# Index(['TOP_OBJECT_X', 'TOP_OBJECT_Y', 'TOP_OBJECT_Z', 'BOTTOM_OBJECT_X',
#        'BOTTOM_OBJECT_Y', 'BOTTOM_OBJECT_Z'],
#       dtype='object')

# %% [markdown]
# ## Loop through all target pairs

# %%
output_path = analysis_path.joinpath('tracks/targets_cal/')

if not output_path.exists():
    output_path.mkdir()

# %%
label_names = ['TOP_OBJECT', 'BOTTOM_OBJECT']

# %%
def cal_and_save():
    extrinsics = vp.get_extrinsic_vals(extrinsic_file)

    # project target points
    df_xyz_new = vp.proc_xyz_targets(extrinsics, s, label_names)

    # save calibrated target locations
    fname = '%s_targets_%s.csv' % (fname_prefix, cal_obj)
    print('save new file: %s' % fname)
    df_xyz_new.to_csv(Path(output_path).joinpath(fname))

# %%
# lists to store reasons for skipping a file
targets_entry_exist = []
cal_obj_record_exist = []
extrinsic_file_exist = []

for idx_main in df_main.index:
    
    s_main = df_main.loc[idx_main, :]
    fname_prefix = '%d_s%d_t%d' % (s_main['DATE'], s_main['SESSION'], s_main['TRIAL'])

    print('---------------------------------------------------')
    print(fname_prefix)
    
    # Find corresponding entry in df_targets
    idx = ((df_targets['DATE']==s_main['DATE']) 
           & (df_targets['SESSION']==s_main['SESSION']) 
           & (df_targets['TRIAL']==s_main['TRIAL']))
    
    if df_targets.loc[idx,:].empty:
        targets_entry_exist.append(False)
        cal_obj_record_exist.append('NaN')
        extrinsic_file_exist.append('NaN')
        print('no df_targets entry found, skipping file...')
        continue
    else:
        targets_entry_exist.append(True)
        s = df_targets.loc[idx, :].squeeze()

        # get cal info
        sel_row = df_cal.loc[(df_cal['DATE']==s['DATE']) & (df_cal['SESSION']==s['SESSION']), :]
        extrinsic_cal_prefix = '%s_s%s_' % (s['DATE'], s['SESSION'])

        # SOME TRIALS HAVE CROSS CAL
        if len(sel_row) == 2:  # sessions with both cross and hula cal obj
            cal_obj = 'cross'
            extrinsic_file = vp.get_extrinsic_filename(extrinsic_cal_prefix, cal_obj)
            extrinsics = vp.get_extrinsic_vals(extrinsic_file)
            if extrinsic_file:  # if extrinsic file exists
                cal_and_save()
            else:
                continue

        # ALL TRIALS HAVE HULA CAL
        flip = sel_row.loc[sel_row['CAL_OBJECT'] == 'hula', 'HULA_HOOP_FLIPPED'].values
        if flip.size > 0:  # if Y/N exists
            cal_obj_record_exist.append(True)
            if flip == 'Y':
                cal_obj = 'hula_flip'
            else:
                cal_obj = 'hula_noflip'
            extrinsic_file = vp.get_extrinsic_filename(extrinsic_cal_prefix, cal_obj)
            if extrinsic_file:  # if extrinsic file exists
                extrinsic_file_exist.append(True)
                cal_and_save()
            else:
                extrinsic_file_exist.append(False)
                print('no extrinsic file, skipping file...')
                continue
        else:
            cal_obj_record_exist.append(False)
            extrinsic_file_exist.append('NaN')
            print('no record for cal object, skipping file...')
            continue
# Out:
# ---------------------------------------------------
# 20190625_s1_t0
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190625_s1_t0
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190625_s1_t1
# save new file: 20190625_s1_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s1_t2
# save new file: 20190625_s1_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s1_t3
# save new file: 20190625_s1_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s1_t4
# save new file: 20190625_s1_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s1_t5
# save new file: 20190625_s1_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s1_t6
# save new file: 20190625_s1_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t1
# save new file: 20190625_s2_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t2
# save new file: 20190625_s2_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t3
# save new file: 20190625_s2_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t4
# save new file: 20190625_s2_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t5
# save new file: 20190625_s2_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t6
# save new file: 20190625_s2_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t7
# save new file: 20190625_s2_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s2_t8
# save new file: 20190625_s2_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190625_s3_t1
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t2
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t3
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t4
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t5
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t6
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t7
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t8
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190625_s3_t9
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190625_s3_t10
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190626_s1_t1
# save new file: 20190626_s1_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t2
# save new file: 20190626_s1_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t3
# save new file: 20190626_s1_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t4
# save new file: 20190626_s1_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t5
# save new file: 20190626_s1_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t6
# save new file: 20190626_s1_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t7
# save new file: 20190626_s1_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t8
# save new file: 20190626_s1_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t9
# save new file: 20190626_s1_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s1_t10
# save new file: 20190626_s1_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s2_t1
# save new file: 20190626_s2_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t2
# save new file: 20190626_s2_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t3
# save new file: 20190626_s2_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t4
# save new file: 20190626_s2_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t5
# save new file: 20190626_s2_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t6
# save new file: 20190626_s2_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t7
# save new file: 20190626_s2_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t8
# save new file: 20190626_s2_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t9
# save new file: 20190626_s2_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s2_t10
# save new file: 20190626_s2_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190626_s3_t1
# save new file: 20190626_s3_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t2
# save new file: 20190626_s3_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t3
# save new file: 20190626_s3_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t4
# save new file: 20190626_s3_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t5
# save new file: 20190626_s3_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t6
# save new file: 20190626_s3_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t7
# save new file: 20190626_s3_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t8
# save new file: 20190626_s3_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t9
# save new file: 20190626_s3_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190626_s3_t10
# save new file: 20190626_s3_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t1
# save new file: 20190627_s1_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t2
# save new file: 20190627_s1_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t3
# save new file: 20190627_s1_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t4
# save new file: 20190627_s1_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t5
# save new file: 20190627_s1_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t6
# save new file: 20190627_s1_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t7
# save new file: 20190627_s1_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t8
# save new file: 20190627_s1_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t9
# save new file: 20190627_s1_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t10
# save new file: 20190627_s1_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s1_t11
# save new file: 20190627_s1_t11_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s2_t1
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190627_s2_t2
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190627_s2_t3
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190627_s2_t4
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190627_s2_t5
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190627_s2_t6
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190627_s2_t7
# save new file: 20190627_s2_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s2_t8
# save new file: 20190627_s2_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s2_t9
# save new file: 20190627_s2_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s2_t10
# save new file: 20190627_s2_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s2_t11
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190627_s3_t1
# save new file: 20190627_s3_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t2
# save new file: 20190627_s3_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t3
# save new file: 20190627_s3_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t4
# save new file: 20190627_s3_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t5
# save new file: 20190627_s3_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t6
# save new file: 20190627_s3_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t7
# save new file: 20190627_s3_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t8
# save new file: 20190627_s3_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t9
# save new file: 20190627_s3_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t10
# save new file: 20190627_s3_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190627_s3_t11
# save new file: 20190627_s3_t11_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t1
# save new file: 20190628_s1_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t2
# save new file: 20190628_s1_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t3
# save new file: 20190628_s1_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t4
# save new file: 20190628_s1_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t5
# save new file: 20190628_s1_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t6
# save new file: 20190628_s1_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t7
# save new file: 20190628_s1_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t8
# save new file: 20190628_s1_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t9
# save new file: 20190628_s1_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s1_t10
# save new file: 20190628_s1_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t1
# save new file: 20190628_s2_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t2
# save new file: 20190628_s2_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t3
# save new file: 20190628_s2_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t4
# save new file: 20190628_s2_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t5
# save new file: 20190628_s2_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t6
# save new file: 20190628_s2_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t7
# save new file: 20190628_s2_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t8
# save new file: 20190628_s2_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t9
# save new file: 20190628_s2_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t10
# save new file: 20190628_s2_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t11
# save new file: 20190628_s2_t11_targets_hula_flip.csv
# ---------------------------------------------------
# 20190628_s2_t12
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190628_s3_t1
# save new file: 20190628_s3_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t2
# save new file: 20190628_s3_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t3
# save new file: 20190628_s3_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t4
# save new file: 20190628_s3_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t5
# save new file: 20190628_s3_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t6
# save new file: 20190628_s3_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t7
# save new file: 20190628_s3_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t8
# save new file: 20190628_s3_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t9
# save new file: 20190628_s3_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190628_s3_t10
# save new file: 20190628_s3_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t1
# save new file: 20190701_s1_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t2
# save new file: 20190701_s1_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t3
# save new file: 20190701_s1_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t4
# save new file: 20190701_s1_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t5
# save new file: 20190701_s1_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t6
# save new file: 20190701_s1_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t7
# save new file: 20190701_s1_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t8
# save new file: 20190701_s1_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t9
# save new file: 20190701_s1_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s1_t10
# save new file: 20190701_s1_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190701_s2_t1
# save new file: 20190701_s2_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t2
# save new file: 20190701_s2_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t3
# save new file: 20190701_s2_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t4
# save new file: 20190701_s2_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t5
# save new file: 20190701_s2_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t6
# save new file: 20190701_s2_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t7
# save new file: 20190701_s2_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t8
# save new file: 20190701_s2_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t9
# save new file: 20190701_s2_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t10
# save new file: 20190701_s2_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s2_t11
# save new file: 20190701_s2_t11_targets_hula_flip.csv
# ---------------------------------------------------
# 20190701_s3_t1
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t2
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t3
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t4
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t5
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t6
# no df_targets entry found, skipping file...
# ---------------------------------------------------
# 20190701_s3_t7
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t8
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t9
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190701_s3_t10
# no record for cal object, skipping file...
# ---------------------------------------------------
# 20190702_s1_t1
# save new file: 20190702_s1_t1_targets_cross.csv
# save new file: 20190702_s1_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t2
# save new file: 20190702_s1_t2_targets_cross.csv
# save new file: 20190702_s1_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t3
# save new file: 20190702_s1_t3_targets_cross.csv
# save new file: 20190702_s1_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t4
# save new file: 20190702_s1_t4_targets_cross.csv
# save new file: 20190702_s1_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t5
# save new file: 20190702_s1_t5_targets_cross.csv
# save new file: 20190702_s1_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t6
# save new file: 20190702_s1_t6_targets_cross.csv
# save new file: 20190702_s1_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t7
# save new file: 20190702_s1_t7_targets_cross.csv
# save new file: 20190702_s1_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t8
# save new file: 20190702_s1_t8_targets_cross.csv
# save new file: 20190702_s1_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t9
# save new file: 20190702_s1_t9_targets_cross.csv
# save new file: 20190702_s1_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s1_t10
# save new file: 20190702_s1_t10_targets_cross.csv
# save new file: 20190702_s1_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t1
# save new file: 20190702_s2_t1_targets_cross.csv
# save new file: 20190702_s2_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t2
# save new file: 20190702_s2_t2_targets_cross.csv
# save new file: 20190702_s2_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t3
# save new file: 20190702_s2_t3_targets_cross.csv
# save new file: 20190702_s2_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t4
# save new file: 20190702_s2_t4_targets_cross.csv
# save new file: 20190702_s2_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t5
# save new file: 20190702_s2_t5_targets_cross.csv
# save new file: 20190702_s2_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t6
# save new file: 20190702_s2_t6_targets_cross.csv
# save new file: 20190702_s2_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t7
# save new file: 20190702_s2_t7_targets_cross.csv
# save new file: 20190702_s2_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t8
# save new file: 20190702_s2_t8_targets_cross.csv
# save new file: 20190702_s2_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t9
# save new file: 20190702_s2_t9_targets_cross.csv
# save new file: 20190702_s2_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t10
# save new file: 20190702_s2_t10_targets_cross.csv
# save new file: 20190702_s2_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s2_t11
# save new file: 20190702_s2_t11_targets_cross.csv
# save new file: 20190702_s2_t11_targets_hula_flip.csv
# ---------------------------------------------------
# 20190702_s3_t1
# save new file: 20190702_s3_t1_targets_cross.csv
# save new file: 20190702_s3_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t2
# save new file: 20190702_s3_t2_targets_cross.csv
# save new file: 20190702_s3_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t3
# save new file: 20190702_s3_t3_targets_cross.csv
# save new file: 20190702_s3_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t4
# save new file: 20190702_s3_t4_targets_cross.csv
# save new file: 20190702_s3_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t5
# save new file: 20190702_s3_t5_targets_cross.csv
# save new file: 20190702_s3_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t6
# save new file: 20190702_s3_t6_targets_cross.csv
# save new file: 20190702_s3_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t7
# save new file: 20190702_s3_t7_targets_cross.csv
# save new file: 20190702_s3_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t8
# save new file: 20190702_s3_t8_targets_cross.csv
# save new file: 20190702_s3_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t9
# save new file: 20190702_s3_t9_targets_cross.csv
# save new file: 20190702_s3_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190702_s3_t10
# save new file: 20190702_s3_t10_targets_cross.csv
# save new file: 20190702_s3_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t1
# save new file: 20190703_s1_t1_targets_cross.csv
# save new file: 20190703_s1_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t2
# save new file: 20190703_s1_t2_targets_cross.csv
# save new file: 20190703_s1_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t3
# save new file: 20190703_s1_t3_targets_cross.csv
# save new file: 20190703_s1_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t4
# save new file: 20190703_s1_t4_targets_cross.csv
# save new file: 20190703_s1_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t5
# save new file: 20190703_s1_t5_targets_cross.csv
# save new file: 20190703_s1_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t6
# save new file: 20190703_s1_t6_targets_cross.csv
# save new file: 20190703_s1_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t7
# save new file: 20190703_s1_t7_targets_cross.csv
# save new file: 20190703_s1_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t8
# save new file: 20190703_s1_t8_targets_cross.csv
# save new file: 20190703_s1_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t9
# save new file: 20190703_s1_t9_targets_cross.csv
# save new file: 20190703_s1_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s1_t10
# save new file: 20190703_s1_t10_targets_cross.csv
# save new file: 20190703_s1_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t1
# save new file: 20190703_s2_t1_targets_cross.csv
# save new file: 20190703_s2_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t2
# save new file: 20190703_s2_t2_targets_cross.csv
# save new file: 20190703_s2_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t3
# save new file: 20190703_s2_t3_targets_cross.csv
# save new file: 20190703_s2_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t4
# save new file: 20190703_s2_t4_targets_cross.csv
# save new file: 20190703_s2_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t5
# save new file: 20190703_s2_t5_targets_cross.csv
# save new file: 20190703_s2_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t6
# save new file: 20190703_s2_t6_targets_cross.csv
# save new file: 20190703_s2_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t7
# save new file: 20190703_s2_t7_targets_cross.csv
# save new file: 20190703_s2_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t8
# save new file: 20190703_s2_t8_targets_cross.csv
# save new file: 20190703_s2_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t9
# save new file: 20190703_s2_t9_targets_cross.csv
# save new file: 20190703_s2_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t10
# save new file: 20190703_s2_t10_targets_cross.csv
# save new file: 20190703_s2_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s2_t11
# save new file: 20190703_s2_t11_targets_cross.csv
# save new file: 20190703_s2_t11_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t1
# save new file: 20190703_s3_t1_targets_cross.csv
# save new file: 20190703_s3_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t2
# save new file: 20190703_s3_t2_targets_cross.csv
# save new file: 20190703_s3_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t3
# save new file: 20190703_s3_t3_targets_cross.csv
# save new file: 20190703_s3_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t4
# save new file: 20190703_s3_t4_targets_cross.csv
# save new file: 20190703_s3_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t5
# save new file: 20190703_s3_t5_targets_cross.csv
# save new file: 20190703_s3_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t6
# save new file: 20190703_s3_t6_targets_cross.csv
# save new file: 20190703_s3_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t7
# save new file: 20190703_s3_t7_targets_cross.csv
# save new file: 20190703_s3_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t8
# save new file: 20190703_s3_t8_targets_cross.csv
# save new file: 20190703_s3_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t9
# save new file: 20190703_s3_t9_targets_cross.csv
# save new file: 20190703_s3_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190703_s3_t10
# save new file: 20190703_s3_t10_targets_cross.csv
# save new file: 20190703_s3_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t1
# save new file: 20190704_s1_t1_targets_cross.csv
# save new file: 20190704_s1_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t2
# save new file: 20190704_s1_t2_targets_cross.csv
# save new file: 20190704_s1_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t3
# save new file: 20190704_s1_t3_targets_cross.csv
# save new file: 20190704_s1_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t4
# save new file: 20190704_s1_t4_targets_cross.csv
# save new file: 20190704_s1_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t5
# save new file: 20190704_s1_t5_targets_cross.csv
# save new file: 20190704_s1_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t6
# save new file: 20190704_s1_t6_targets_cross.csv
# save new file: 20190704_s1_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t7
# save new file: 20190704_s1_t7_targets_cross.csv
# save new file: 20190704_s1_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t8
# save new file: 20190704_s1_t8_targets_cross.csv
# save new file: 20190704_s1_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t9
# save new file: 20190704_s1_t9_targets_cross.csv
# save new file: 20190704_s1_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s1_t10
# save new file: 20190704_s1_t10_targets_cross.csv
# save new file: 20190704_s1_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t1
# save new file: 20190704_s2_t1_targets_cross.csv
# save new file: 20190704_s2_t1_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t2
# save new file: 20190704_s2_t2_targets_cross.csv
# save new file: 20190704_s2_t2_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t3
# save new file: 20190704_s2_t3_targets_cross.csv
# save new file: 20190704_s2_t3_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t4
# save new file: 20190704_s2_t4_targets_cross.csv
# save new file: 20190704_s2_t4_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t5
# save new file: 20190704_s2_t5_targets_cross.csv
# save new file: 20190704_s2_t5_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t6
# save new file: 20190704_s2_t6_targets_cross.csv
# save new file: 20190704_s2_t6_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t7
# save new file: 20190704_s2_t7_targets_cross.csv
# save new file: 20190704_s2_t7_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t8
# save new file: 20190704_s2_t8_targets_cross.csv
# save new file: 20190704_s2_t8_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t9
# save new file: 20190704_s2_t9_targets_cross.csv
# save new file: 20190704_s2_t9_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t10
# save new file: 20190704_s2_t10_targets_cross.csv
# save new file: 20190704_s2_t10_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s2_t11
# save new file: 20190704_s2_t11_targets_cross.csv
# save new file: 20190704_s2_t11_targets_hula_noflip.csv
# ---------------------------------------------------
# 20190704_s3_t1
# save new file: 20190704_s3_t1_targets_cross.csv
# save new file: 20190704_s3_t1_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t2
# save new file: 20190704_s3_t2_targets_cross.csv
# save new file: 20190704_s3_t2_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t3
# save new file: 20190704_s3_t3_targets_cross.csv
# save new file: 20190704_s3_t3_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t4
# save new file: 20190704_s3_t4_targets_cross.csv
# save new file: 20190704_s3_t4_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t5
# save new file: 20190704_s3_t5_targets_cross.csv
# save new file: 20190704_s3_t5_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t6
# save new file: 20190704_s3_t6_targets_cross.csv
# save new file: 20190704_s3_t6_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t7
# save new file: 20190704_s3_t7_targets_cross.csv
# save new file: 20190704_s3_t7_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t8
# save new file: 20190704_s3_t8_targets_cross.csv
# save new file: 20190704_s3_t8_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t9
# save new file: 20190704_s3_t9_targets_cross.csv
# save new file: 20190704_s3_t9_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t10
# save new file: 20190704_s3_t10_targets_cross.csv
# save new file: 20190704_s3_t10_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t11
# save new file: 20190704_s3_t11_targets_cross.csv
# save new file: 20190704_s3_t11_targets_hula_flip.csv
# ---------------------------------------------------
# 20190704_s3_t12
# save new file: 20190704_s3_t12_targets_cross.csv
# save new file: 20190704_s3_t12_targets_hula_flip.csv

# %%
# Sanity check of dimension
len(extrinsic_file_exist), len(cal_obj_record_exist), len(targets_entry_exist)
# Out:
# (247, 247, 247)

# %%
len(df_main)
# Out:
# 247

# %% [markdown]
# ## Append column to main dataframe for whether extrinsics and cal obj info exist

# %%
df_main['targets_entry_exist'] = targets_entry_exist

# %%
# Sanity check: these two columns should match
(df_main['targets_entry_exist'] == df_main['target_position_assembled_in_csv']).all()
# Out:
# True

# %%
df_main['extrinsic_file_exist'] = extrinsic_file_exist
df_main['cal_obj_record_exist'] = cal_obj_record_exist

# %%
df_main.to_csv(analysis_path.joinpath('all_info_csv/main_info_append_02.csv'))
